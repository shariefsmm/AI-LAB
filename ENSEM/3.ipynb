# %%
import numpy as np
import math as mat
from scipy.stats import poisson
# poission.pmf(k,Lambda)
V=np.zeros((20,10,10))
R=np.zeros((20,10,10),dtype='float32')
LambdaL=[3,2,2]
LambdaR=[3,1,1]
P=np.zeros((20,10,10))
Action=[1,2,3,4,5]
gamma=0.9

# %%
def Get_reward():
	sum1=0
	sum2=0
	sum3=0
	for i in range(20):
		sum1=0
		# print(i)
		for temp in range(i+1):
			sum1=sum1+poisson.pmf(temp,LambdaL[0])
		# print(sum1)
		for j in range(10):
			sum2=0
			for temp in range(j+1):
				sum2=sum2+poisson.pmf(temp,LambdaL[1])
			for k in range(10):
				sum3=0
				for temp in range(k+1):
					sum3=sum3+poisson.pmf(temp,LambdaL[0])
			# print(sum1,sum2,sum3,(sum1+sum2+sum3)*10)
				R[i][j][k]=(sum1+sum2+sum3)*10
			# if(R[i][j][k]!=0 and k!=9):print(R[i][j][k])
            
Get_reward()
print(R)
# Out:
# [[[ 2.3490942  3.8427062  6.083124  ... 11.732179  11.813193  11.8401985]
#   [ 5.0558     6.549412   8.78983   ... 14.438884  14.519899  14.546905 ]
#   [ 7.7625055  9.256118  11.496535  ... 17.14559   17.226604  17.25361  ]
#   ...
#   [10.984775  12.478386  14.718804  ... 20.367859  20.448874  20.475878 ]
#   [10.993367  12.486979  14.727397  ... 20.376451  20.457466  20.484472 ]
#   [10.995276  12.488889  14.729306  ... 20.37836   20.459375  20.486382 ]]
#
#  [[ 3.8427062  5.3363185  7.5767365 ... 13.225791  13.306806  13.333811 ]
#   [ 6.549412   8.043024  10.2834425 ... 15.932496  16.013512  16.040516 ]
#   [ 9.256118  10.749729  12.990148  ... 18.639202  18.720217  18.747223 ]
#   ...
#   [12.478386  13.971998  16.212416  ... 21.861471  21.942486  21.96949  ]
#   [12.486979  13.980591  16.221008  ... 21.870064  21.951078  21.978083 ]
#   [12.488889  13.9825    16.22292   ... 21.871973  21.952988  21.979994 ]]
#
#  [[ 6.083124   7.5767365  9.817155  ... 15.466208  15.547224  15.574228 ]
#   [ 8.78983   10.2834425 12.52386   ... 18.172915  18.25393   18.280935 ]
#   [11.496535  12.990148  15.230566  ... 20.87962   20.960634  20.98764  ]
#   ...
#   [14.718804  16.212416  18.452835  ... 24.101889  24.182903  24.20991  ]
#   [14.727397  16.221008  18.461428  ... 24.110481  24.191496  24.218502 ]
#   [14.729306  16.22292   18.463337  ... 24.11239   24.193405  24.220411 ]]
#
#  ...
#
#  [[11.851224  13.344835  15.585254  ... 21.234308  21.315323  21.342327 ]
#   [14.557929  16.05154   18.29196   ... 23.941013  24.022028  24.049034 ]
#   [17.264635  18.758247  20.998665  ... 26.647718  26.728735  26.75574  ]
#   ...
#   [20.486904  21.980516  24.220934  ... 29.869987  29.951002  29.978008 ]
#   [20.495497  21.989109  24.229527  ... 29.87858   29.959595  29.9866   ]
#   [20.497406  21.991018  24.231436  ... 29.88049   29.961506  29.98851  ]]
#
#  [[11.851224  13.344835  15.585254  ... 21.234308  21.315323  21.342327 ]
#   [14.557929  16.05154   18.29196   ... 23.941013  24.022028  24.049034 ]
#   [17.264635  18.758247  20.998665  ... 26.647718  26.728735  26.75574  ]
#   ...
#   [20.486904  21.980516  24.220934  ... 29.869987  29.951002  29.978008 ]
#   [20.495497  21.989109  24.229527  ... 29.87858   29.959595  29.9866   ]
#   [20.497406  21.991018  24.231436  ... 29.88049   29.961506  29.98851  ]]
#
#  [[11.851224  13.344835  15.585254  ... 21.234308  21.315323  21.342327 ]
#   [14.557929  16.05154   18.29196   ... 23.941013  24.022028  24.049034 ]
#   [17.264635  18.758247  20.998665  ... 26.647718  26.728735  26.75574  ]
#   ...
#   [20.486904  21.980516  24.220934  ... 29.869987  29.951002  29.978008 ]
#   [20.495497  21.989109  24.229527  ... 29.87858   29.959595  29.9866   ]
#   [20.497406  21.991018  24.231436  ... 29.88049   29.961506  29.98851  ]]]

# %%
def find(i,j,k,a,P):
	x=y=z=0
	temp=0
	cost=0
	c=0
	count=0
	total=0.0
	for x in range(20):
		for y in range(10):
			for z in range(10):
				count=abs(x-i)+abs(y-j)+abs(z-k)
				count=count/2
				error1=y-j
				error2=z-k
				correction=0
				if error1*error2<0:correction=min(abs(error1),abs(error2))
				if count==a:
					total+=1
					cost=-2*count + 2*correction
					if cost>0 : print(cost)
					temp=temp+P[x][y][z] +cost
				# if i==16 and j==6 and k==9:
				# 	print("temp is ",temp)
					# for t1 in range(x+1,20):
					# 	sum1=0
					# 	for temp in range(t1-x):
					# 		sum1=sum1+poisson.pmf(temp,LambdaR[0])
					# 	for t2 in range(y+1,10):
					# 		sum2=0
					# 		for temp in range(t2-y):
					# 			sum2=sum2+poisson.pmf(temp,LambdaR[1])
					# 		for t3 in range(z+1,10):
					# 			sum3=0
					# 			for temp in range(t3-z):
					# 				sum3=sum3+poisson.pmf(temp,LambdaR[1])
					# 			temp=temp+(sum1*sum2*sum3)*P[t1][t2][t3]
	return (temp)/total

# %%
def value_iteration():
	print("Value_iteration started")
	itr=0;
	while(1):
		itr+=1
		print("Iteration number is ",itr)
		threshold=-1
		Prev=V.copy()
		for i in range(20):
			for j in range(10):
				for k in range(10):
					l=[]
					for a in Action:
						# print("went")
						temp=find(i,j,k,a,Prev)
						# print('out')
						l.append(R[i][j][k]+gamma*temp)
					V[i][j][k]=np.max(l)
					P[i][j][k]=np.argmax(l)
					if abs(V[i][j][k]-Prev[i][j][k])>threshold:value=[i,j,k]
					threshold=max(threshold,abs(V[i][j][k]-Prev[i][j][k]))
		# print("after change")
		# print(V)
		# print("before change")
		# print(Prev)
		if threshold<=0.1:break
		print("Threshold ",threshold)

	print("value_iteration completed")
	print("values")
	print(V)
	print("policy")
	print(P)

# %%
value_iteration()
# Out:
# Value_iteration started
# Iteration number is  1
# Threshold  28.486867453835227
# Iteration number is  2
# Threshold  25.51639949512482
# Iteration number is  3
# Threshold  22.924748305271542
# Iteration number is  4
# Threshold  20.59085151516433
# Iteration number is  5
# Threshold  18.489358782183857
# Iteration number is  6
# Threshold  16.590638081319923
# Iteration number is  7
# Threshold  14.878454879569546
# Iteration number is  8
# Threshold  13.335792610266282
# Iteration number is  9
# Threshold  11.948315086392284
# Iteration number is  10
# Threshold  10.702579041502275
# Iteration number is  11
# Threshold  9.585804298631757
# Iteration number is  12
# Threshold  8.585931893036843
# Iteration number is  13
# Threshold  7.691565603950494
# Iteration number is  14
# Threshold  6.892005896962644
# Iteration number is  15
# Threshold  6.177339832555475
# Iteration number is  16
# Threshold  5.538764138246279
# Iteration number is  17
# Threshold  4.968261202851977
# Iteration number is  18
# Threshold  4.457911296576668
# Iteration number is  19
# Threshold  4.0013555996082175
# Iteration number is  20
# Threshold  3.5927470586482855
# Iteration number is  21
# Threshold  3.2266136626995774
# Iteration number is  22
# Threshold  2.898388901435851
# Iteration number is  23
# Threshold  2.6040252916628788
# Iteration number is  24
# Threshold  2.340031940553132
# Iteration number is  25
# Threshold  2.103176833642152
# Iteration number is  26
# Threshold  1.8905219032031368
# Iteration number is  27
# Threshold  1.6995982869486284
# Iteration number is  28
# Threshold  1.528082671229015
# Iteration number is  29
# Threshold  1.3739755737612995
# Iteration number is  30
# Threshold  1.2354896002544251
# Iteration number is  31
# Threshold  1.111025313208927
# Iteration number is  32
# Threshold  0.9991504644319775
# Iteration number is  33
# Threshold  0.8985817788349095
# Iteration number is  34
# Threshold  0.8081688387846953
# Iteration number is  35
# Threshold  0.726879907684463
# Iteration number is  36
# Threshold  0.6537893240384278
# Iteration number is  37
# Threshold  0.5880663278782094
# Iteration number is  38
# Threshold  0.5289651159166624
# Iteration number is  39
# Threshold  0.4758159892929257
# Iteration number is  40
# Threshold  0.4280174585279042
# Iteration number is  41
# Threshold  0.3850291980546672
# Iteration number is  42
# Threshold  0.346365748416531
# Iteration number is  43
# Threshold  0.3115908844471278
# Iteration number is  44
# Threshold  0.2803125750052686
# Iteration number is  45
# Threshold  0.25217846851120385
# Iteration number is  46
# Threshold  0.22687184738867927
# Iteration number is  47
# Threshold  0.20410800124238904
# Iteration number is  48
# Threshold  0.18363097384269622
# Iteration number is  49
# Threshold  0.16521064439018573
# Iteration number is  50
# Threshold  0.1486401078726658
# Iteration number is  51
# Threshold  0.13373332327341814
# Iteration number is  52
# Threshold  0.12032300177480693
# Iteration number is  53
# Threshold  0.10825871011610388
# Iteration number is  54
# value_iteration completed
# values
# [[[195.34149283 198.07816088 201.72016633 ... 213.71812909 214.03447376
#    213.75239155]
#   [199.30620344 202.26163681 206.0095342  ... 217.93638989 217.9886723
#    217.3232612 ]
#   [203.41175227 206.47914885 210.49904225 ... 221.89919755 221.64888758
#    221.09516782]
#   ...
#   [211.44482449 214.63781291 218.36193383 ... 227.82097392 228.22440089
#    228.22460092]
#   [211.45665579 214.37413257 217.79426148 ... 227.72242108 228.60154377
#    228.56700019]
#   [211.02988888 213.49653857 217.00228123 ... 227.51517333 228.26070231
#    228.23177554]]
#
#  [[197.76035136 200.70739382 204.61423598 ... 217.06349094 217.1621751
#    216.62824472]
#   [201.95774707 205.1104008  209.25024903 ... 221.30039676 220.84954149
#    220.03642463]
#   [206.33119807 209.7296834  213.87573834 ... 224.9376844  224.29005051
#    223.65864023]
#   ...
#
#  [[4. 4. 4. ... 4. 4. 4.]
#   [4. 4. 4. ... 4. 4. 4.]
#   [4. 4. 4. ... 4. 4. 3.]
#   ...
#   [4. 4. 4. ... 2. 2. 1.]
#   [4. 4. 4. ... 2. 1. 1.]
#   [4. 4. 4. ... 1. 1. 1.]]
#
#  ...
#
#  [[4. 4. 4. ... 2. 2. 2.]
#   [4. 4. 4. ... 2. 2. 2.]
#   [4. 4. 4. ... 0. 0. 0.]
#   ...
#   [4. 4. 2. ... 0. 0. 0.]
#   [4. 2. 2. ... 0. 0. 0.]
#   [3. 3. 2. ... 0. 0. 0.]]
#
#  [[4. 4. 4. ... 2. 2. 2.]
#   [4. 4. 4. ... 2. 2. 2.]
#   [4. 4. 3. ... 0. 0. 0.]
#   ...
#   [4. 2. 2. ... 0. 0. 0.]
#   [4. 2. 2. ... 0. 0. 0.]
#   [3. 3. 2. ... 0. 0. 0.]]
#
#  [[4. 4. 4. ... 2. 2. 2.]
#   [4. 4. 4. ... 1. 1. 2.]
#   [4. 4. 3. ... 0. 0. 0.]
#   ...
#   [4. 3. 2. ... 0. 0. 0.]
#   [4. 2. 2. ... 0. 0. 0.]
#   [3. 3. 2. ... 0. 0. 0.]]]

# %%
def find1(i,j,k,a,P):
	x=y=z=0
	temp=0
	cost=0
	c=0
	count=0
	total=0.0
	for x in range(20):
		for y in range(10):
			for z in range(10):
				count=abs(x-i)+abs(y-j)+abs(z-k)
				count=count/2
				error1=y-j
				error2=z-k
				correction=0
				if error1*error2<0:correction=min(abs(error1),abs(error2))
				if count==a:
					total+=1
					cost=-2*count + 2*correction
					if cost>0 : print(cost)
					temp=temp+P[x][y][z] +cost
				# if i==16 and j==6 and k==9:
				# 	print("temp is ",temp)
					for t1 in range(x+1,20):
						sum1=0
						temp1=t1-x
						sum1=sum1+poisson.pmf(temp1,LambdaR[0])
						for t2 in range(y+1,10):
							sum2=0
							temp1=t2-y
							sum2=sum2+poisson.pmf(temp1,LambdaR[1])
							for t3 in range(z+1,10):
								sum3=0
								temp1=t3-z
								sum3=sum3+poisson.pmf(temp1,LambdaR[1])
								temp=temp+(sum1*sum2*sum3)*P[t1][t2][t3]
	if temp==0.0:return 0.0
	return (temp)/total

# %%
def value_iteration1():
	print("Value_iteration started")
	itr=0;
	while(1):
		itr+=1
		print("Iteration number is ",itr)
		threshold=-1
		Prev=V.copy()
		for i in range(20):
			for j in range(10):
				for k in range(10):
# 					print(k)
					l=[]
					for a in Action:
						# print("went")
						temp=find1(i,j,k,a,Prev)
						# print('out')
						l.append(R[i][j][k]+gamma*temp)
					V[i][j][k]=np.max(l)
					P[i][j][k]=np.argmax(l)
					if abs(V[i][j][k]-Prev[i][j][k])>threshold:value=[i,j,k]
					threshold=max(threshold,abs(V[i][j][k]-Prev[i][j][k]))
		# print("after change")
		# print(V)
		# print("before change")
		# print(Prev)
		if threshold<=0.1:break
		print("Threshold ",threshold)

	print("value_iteration completed")
	print("values")
	print(V)
	print("policy")
	print(P)

# %%
value_iteration1()
# Out:
# Value_iteration started
# Iteration number is  1
